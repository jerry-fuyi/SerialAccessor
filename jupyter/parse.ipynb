# %% [markdown]
# The STM32 SVD files are located at:
#
# \<CubeIDE Directory\>\STM32CubeIDE\plugins\com.st.stm32cube.ide.mcu.productdb.debug_xxxxxx\resources\cmsis\STMicroelectronics_CMSIS_SVD\
#
# Copy the `.SVD` file to the same directory as this notebook.
#
# Change the `model` according to the model.
#
# Then run all cells, and a python file will be generated, named by the model. Import it in your application code.

# %%
model = "g474"

# %%
import xml.etree.ElementTree as ET
import re
import copy

# %%
def get_description(node):
    if node.find("description") is None:
        desc = ""
    else:
        desc = node.find("description").text
        desc = desc.replace("\n", ". ", 1)
    return " ".join(desc.split())

# %%
root = ET.parse(f"./stm32{model}.svd").getroot().find("peripherals")
for child in root:
    print(child.tag, child.find("name").text, child.attrib)
# Out:
# peripheral CRC {}
# peripheral IWDG {}
# peripheral WWDG {}
# peripheral I2C1 {}
# peripheral I2C2 {'derivedFrom': 'I2C1'}
# peripheral I2C3 {'derivedFrom': 'I2C1'}
# peripheral I2C4 {'derivedFrom': 'I2C1'}
# peripheral FLASH {}
# peripheral DBGMCU {}
# peripheral RCC {}
# peripheral PWR {}
# peripheral RNG {}
# peripheral GPIOA {}
# peripheral GPIOB {}
# peripheral GPIOC {}
# peripheral GPIOD {'derivedFrom': 'GPIOC'}
# peripheral GPIOE {'derivedFrom': 'GPIOC'}
# peripheral GPIOF {'derivedFrom': 'GPIOC'}
# peripheral GPIOG {'derivedFrom': 'GPIOC'}
# peripheral TIM15 {}
# peripheral TIM16 {}
# peripheral TIM17 {'derivedFrom': 'TIM16'}
# peripheral TIM1 {}
# peripheral TIM20 {'derivedFrom': 'TIM1'}
# peripheral TIM8 {'derivedFrom': 'TIM1'}
# peripheral TIM2 {}
# peripheral TIM3 {'derivedFrom': 'TIM2'}
# peripheral TIM4 {'derivedFrom': 'TIM2'}
# peripheral TIM5 {'derivedFrom': 'TIM2'}
# peripheral TIM6 {}
# peripheral TIM7 {'derivedFrom': 'TIM6'}
# peripheral LPTIMER1 {}
# peripheral USART1 {}
# peripheral USART2 {'derivedFrom': 'USART1'}
# peripheral USART3 {'derivedFrom': 'USART1'}
# peripheral UART4 {}
# peripheral UART5 {'derivedFrom': 'UART4'}
# peripheral LPUART1 {}
# peripheral SPI1 {}
# peripheral SPI4 {}
# peripheral SPI3 {'derivedFrom': 'SPI4'}
# peripheral SPI2 {'derivedFrom': 'SPI4'}
# peripheral EXTI {}
# peripheral RTC {}
# peripheral FMC {}
# peripheral DMA1 {}
# peripheral DMA2 {'derivedFrom': 'DMA1'}
# peripheral DMAMUX {}
# peripheral SYSCFG {}
# peripheral VREFBUF {}
# peripheral COMP {}
# peripheral OPAMP {}
# peripheral HRTIM_Master {}
# peripheral HRTIM_TIMA {}
# peripheral HRTIM_TIMB {}
# peripheral HRTIM_TIMC {}
# peripheral HRTIM_TIMD {}
# peripheral HRTIM_TIME {}
# peripheral HRTIM_TIMF {}
# peripheral HRTIM_Common {}
# peripheral QUADSPI {}
# peripheral DAC1 {}
# peripheral DAC2 {'derivedFrom': 'DAC1'}
# peripheral DAC3 {'derivedFrom': 'DAC1'}
# peripheral DAC4 {'derivedFrom': 'DAC1'}
# peripheral ADC1 {}
# peripheral ADC2 {'derivedFrom': 'ADC1'}
# peripheral ADC3 {}
# peripheral ADC4 {'derivedFrom': 'ADC1'}
# peripheral ADC5 {'derivedFrom': 'ADC3'}
# peripheral ADC12_Common {}
# peripheral ADC345_Common {'derivedFrom': 'ADC12_Common'}
# peripheral FMAC {}
# peripheral CORDIC {}
# peripheral SAI {}
# peripheral TAMP {}
# peripheral FDCAN {}
# peripheral FDCAN1 {'derivedFrom': 'FDCAN'}
# peripheral FDCAN2 {'derivedFrom': 'FDCAN'}
# peripheral FDCAN3 {'derivedFrom': 'FDCAN'}
# peripheral UCPD1 {}
# peripheral USB_FS_device {}
# peripheral CRS {}

# %%
info = {}

for peri in root:
    periname = peri.find("name").text
    periname_simple = re.sub(r"\d+$", "", periname)
    
    info[periname] = {}
    info[periname]["address"] = int(peri.find("baseAddress").text, base=16)

    if peri.attrib.get("derivedFrom"):
        basename = peri.attrib.get("derivedFrom")
        info[periname]["base"] = basename
        continue

    info[periname]["description"] = get_description(peri)
    regsinfo = {}
    info[periname]["registers"] = regsinfo

    regs = peri.find("registers")
    for reg in regs:
        regname = reg.find("name").text
        regname_simple = re.sub(f"^({periname}_|{periname}|{periname_simple}_|{periname_simple})", "", regname)
        if re.findall(r"^\d", regname_simple):
            regname = regname
        else:
            regname = regname_simple
        regsinfo[regname] = {}
        regsinfo[regname]["description"] = get_description(reg)
        regsinfo[regname]["addressOffset"] = int(reg.find("addressOffset").text, base=16)
        reg_access = reg.find("access")
        if reg_access is None:
            reg_access = ""
        else:
            reg_access = reg_access.text
        regsinfo[regname]["resetValue"] = int(reg.find("resetValue").text, base=16)
        fieldsinfo = {}
        regsinfo[regname]["fields"] = fieldsinfo
        
        fields = reg.find("fields")
        if fields is None:
            continue
        for field in fields:
            finfo = {}
            fname = field.find("name").text
            fieldsinfo[fname] = finfo
            finfo["description"] = get_description(field)
            offset = int(field.find("bitOffset").text)
            width = int(field.find("bitWidth").text)
            finfo["mask"] = (2**width - 1) * 2**offset
            field_access = field.find("access")
            if field_access is None:
                field_access = ""
            else:
                field_access = field_access.text
            finfo["access"] = reg_access + field_access

        toremove = set()
        for fname, finfo in fieldsinfo.items():
            if re.findall(r"(_\d+)+$", fname):
                fname_simple = re.sub(r"(_\d+)+$", "", fname)
                if fname_simple in fieldsinfo:
                    fieldsinfo[fname_simple]["mask"] |= finfo["mask"]
                    toremove.add(fname)
        for fname in toremove:
            fieldsinfo.pop(fname)

    tomerge = {}
    for regname, reginfo in regsinfo.items():
        if re.findall("(_Input|_Output)$", regname):
            regname_simple = re.sub("(_Input|_Output)$", "", regname)
            if regname_simple in tomerge:
                tomerge[regname_simple]["fields"] |= regsinfo[regname]["fields"]
            else:
                tomerge[regname_simple] = copy.deepcopy(regsinfo[regname])
                tomerge[regname_simple]["description"] = re.sub(r"\([^)]*\)", "",
                    tomerge[regname_simple]["description"]).rstrip(" ")
    regsinfo |= tomerge

info
# Out:
# {'CRC': {'address': 1073885184,
#   'description': 'Cyclic redundancy check calculation unit',
#   'registers': {'DR': {'description': 'Data register',
#     'addressOffset': 0,
#     'resetValue': 4294967295,
#     'fields': {'DR': {'description': 'Data register bits',
#       'mask': 4294967295,
#       'access': 'read-write'}}},
#    'IDR': {'description': 'Independent data register',
#     'addressOffset': 4,
#     'resetValue': 0,
#     'fields': {'IDR': {'description': 'General-purpose 8-bit data register bits',
#       'mask': 4294967295,
#       'access': 'read-write'}}},
#    'CR': {'description': 'Control register',
#     'addressOffset': 8,
#     'resetValue': 0,
#     'fields': {'REV_OUT': {'description': 'Reverse output data',
#       'mask': 128,
#       'access': 'read-write'},
#      'REV_IN': {'description': 'Reverse input data',
#       'mask': 96,
#       'access': 'read-write'},
#      'POLYSIZE': {'description': 'Polynomial size',
#       'mask': 24,
#       'access': 'read-write'},
#      'RESET': {'description': 'RESET bit',
#       'mask': 1,
#       'access': 'write-only'}}},
#    'INIT': {'description': 'Initial CRC value',
#     'addressOffset': 16,
#     'resetValue': 4294967295,
#     'fields': {'CRC_INIT': {'description': 'Programmable initial CRC value',
#       'mask': 4294967295,
#       'access': 'read-write'}}},
#    'POL': {'description': 'polynomial',
#     'addressOffset': 20,
#     'resetValue': 79764919,
#     'fields': {'POL': {'description': 'Programmable polynomial',
#       'mask': 4294967295,
#       'access': 'read-write'}}}}},
#  'IWDG': {'address': 1073754112,
#   'description': 'WinWATCHDOG',
#   'registers': {'KR': {'description': 'Key register',
#     'addressOffset': 0,
#     'resetValue': 0,
#     'fields': {'KEY': {'description': 'Key value (write only, read 0x0000)',
#       'mask': 65535,
#       'access': 'write-only'}}},
#    'PR': {'description': 'Prescaler register',
#     'addressOffset': 4,
#     'resetValue': 0,
#     'fields': {'PR': {'description': 'Prescaler divider',
#       'mask': 7,
#       'access': 'read-write'}}},
#    'RLR': {'description': 'Reload register',
#     'addressOffset': 8,
#     'resetValue': 4095,
#     'fields': {'RL': {'description': 'Watchdog counter reload value',
#       'mask': 4095,
#       'access': 'read-write'}}},
#    'SR': {'description': 'Status register',
#     'addressOffset': 12,
#     'resetValue': 0,
#     'fields': {'WVU': {'description': 'Watchdog counter window value update',
#       'mask': 4,
#       'access': 'read-only'},
#      'RVU': {'description': 'Watchdog counter reload value update',
#       'mask': 2,
#       'access': 'read-only'},
#      'PVU': {'description': 'Watchdog prescaler value update',
#       'mask': 1,
#       'access': 'read-only'}}},
#    'WINR': {'description': 'Window register',
#     'addressOffset': 16,
#     'resetValue': 4095,
#     'fields': {'WIN': {'description': 'Watchdog counter window value',
#       'mask': 4095,
#       'access': 'read-write'}}}}},
#  'WWDG': {'address': 1073753088,
#   'description': 'System window watchdog',
#   'registers': {'CR': {'description': 'Control register',
#     'addressOffset': 0,
#     'resetValue': 127,
#     'fields': {'WDGA': {'description': 'Activation bit',
#       'mask': 128,
#       'access': 'read-write'},
#      'T': {'description': '7-bit counter (MSB to LSB)',
#       'mask': 127,
#       'access': 'read-write'}}},
#    'CFR': {'description': 'Configuration register',
#     'addressOffset': 4,
#     'resetValue': 127,
#     'fields': {'WDGTB': {'description': 'Timer base',
#       'mask': 14336,
#       'access': 'read-write'},
#      'EWI': {'description': 'Early wakeup interrupt',
#       'mask': 512,
#       'access': 'read-write'},
#      'W': {'description': '7-bit window value',
#       'mask': 127,
#       'access': 'read-write'}}},
#    'SR': {'description': 'Status register',
#     'addressOffset': 8,
#     'resetValue': 0,
#     'fields': {'EWIF': {'description': 'Early wakeup interrupt flag',
#       'mask': 1,
#       'access': 'read-write'}}}}},
#  'I2C1': {'address': 1073763328,
#   'description': 'Inter-integrated circuit',
#   'registers': {'CR1': {'description': 'Control register 1',
#     'addressOffset': 0,
#     'resetValue': 0,
#     'fields': {'PE': {'description': 'Peripheral enable',
#       'mask': 1,
#       'access': 'read-write'},
#      'TXIE': {'description': 'TX Interrupt enable',
#       'mask': 2,
#       'access': 'read-write'},
#      'RXIE': {'description': 'RX Interrupt enable',
#       'mask': 4,
#       'access': 'read-write'},
#      'ADDRIE': {'description': 'Address match interrupt enable (slave only)',
#       'mask': 8,
#       'access': 'read-write'},
#      'NACKIE': {'description': 'Not acknowledge received interrupt enable',
#       'mask': 16,
#       'access': 'read-write'},
#      'STOPIE': {'description': 'STOP detection Interrupt enable',
#       'mask': 32,
#       'access': 'read-write'},
#      'TCIE': {'description': 'Transfer Complete interrupt enable',
#       'mask': 64,
#       'access': 'read-write'},
#      'ERRIE': {'description': 'Error interrupts enable',
#       'mask': 128,
#       'access': 'read-write'},
#      'DNF': {'description': 'Digital noise filter',
#       'mask': 3840,
#       'access': 'read-write'},
#      'ANFOFF': {'description': 'Analog noise filter OFF',
#       'mask': 4096,
#       'access': 'read-write'},
#      'TXDMAEN': {'description': 'DMA transmission requests enable',
#       'mask': 16384,
#       'access': 'read-write'},
#      'RXDMAEN': {'description': 'DMA reception requests enable',
#       'mask': 32768,
#       'access': 'read-write'},
#      'SBC': {'description': 'Slave byte control',
#       'mask': 65536,
#       'access': 'read-write'},
#      'NOSTRETCH': {'description': 'Clock stretching disable',
#       'mask': 131072,
#       'access': 'read-write'},
#      'WUPEN': {'description': 'Wakeup from STOP enable',
#       'mask': 262144,
#       'access': 'read-write'},
#      'GCEN': {'description': 'General call enable',
#       'mask': 524288,
#       'access': 'read-write'},
#      'SMBHEN': {'description': 'SMBus Host address enable',
#       'mask': 1048576,
#       'access': 'read-write'},
#      'SMBDEN': {'description': 'SMBus Device Default address enable',
#       'mask': 2097152,
#       'access': 'read-write'},
#      'ALERTEN': {'description': 'SMBUS alert enable',
#       'mask': 4194304,
#       'access': 'read-write'},
#      'PECEN': {'description': 'PEC enable',
#       'mask': 8388608,
#       'access': 'read-write'}}},
#    'CR2': {'description': 'Control register 2',
#     'addressOffset': 4,
#     'resetValue': 0,
#     'fields': {'PECBYTE': {'description': 'Packet error checking byte',
#       'mask': 67108864,
#       'access': 'read-write'},
#      'AUTOEND': {'description': 'Automatic end mode (master mode)',
#       'mask': 33554432,
#       'access': 'read-write'},
#      'RELOAD': {'description': 'NBYTES reload mode',
#       'mask': 16777216,
#       'access': 'read-write'},
#      'NBYTES': {'description': 'Number of bytes',
#       'mask': 16711680,
#       'access': 'read-write'},
#      'NACK': {'description': 'NACK generation (slave mode)',
#       'mask': 32768,
#       'access': 'read-write'},
#      'STOP': {'description': 'Stop generation (master mode)',
#       'mask': 16384,
#       'access': 'read-write'},
#      'START': {'description': 'Start generation',
#       'mask': 8192,
#       'access': 'read-write'},
#      'HEAD10R': {'description': '10-bit address header only read direction (master receiver mode)',
#       'mask': 4096,
#       'access': 'read-write'},
#      'ADD10': {'description': '10-bit addressing mode (master mode)',
#       'mask': 2048,
#       'access': 'read-write'},
#      'RD_WRN': {'description': 'Transfer direction (master mode)',
#       'mask': 1024,
#       'access': 'read-write'},
#      'SADD': {'description': 'Slave address bit (master mode)',
#       'mask': 1023,
#       'access': 'read-write'}}},
#    'OAR1': {'description': 'Own address register 1',
#     'addressOffset': 8,
#     'resetValue': 0,
#     'fields': {'OA1': {'description': 'Interface address',
#       'mask': 1023,
#       'access': 'read-write'},
#      'OA1MODE': {'description': 'Own Address 1 10-bit mode',
#       'mask': 1024,
#       'access': 'read-write'},
#      'OA1EN': {'description': 'Own Address 1 enable',
#       'mask': 32768,
#       'access': 'read-write'}}},
#    'OAR2': {'description': 'Own address register 2',
#     'addressOffset': 12,
#     'resetValue': 0,
#     'fields': {'OA2': {'description': 'Interface address',
#       'mask': 254,
#       'access': 'read-write'},
#      'OA2MSK': {'description': 'Own Address 2 masks',
#       'mask': 1792,
#       'access': 'read-write'},
#      'OA2EN': {'description': 'Own Address 2 enable',
#       'mask': 32768,
#       'access': 'read-write'}}},
#    'TIMINGR': {'description': 'Timing register',
#     'addressOffset': 16,
#     'resetValue': 0,
#     'fields': {'SCLL': {'description': 'SCL low period (master mode)',
#       'mask': 255,
#       'access': 'read-write'},
#      'SCLH': {'description': 'SCL high period (master mode)',
#       'mask': 65280,
#       'access': 'read-write'},
#      'SDADEL': {'description': 'Data hold time',
#       'mask': 983040,
#       'access': 'read-write'},
#      'SCLDEL': {'description': 'Data setup time',
#       'mask': 15728640,
#       'access': 'read-write'},
#      'PRESC': {'description': 'Timing prescaler',
#       'mask': 4026531840,
#       'access': 'read-write'}}},
#    'TIMEOUTR': {'description': 'Status register 1',
#     'addressOffset': 20,
#     'resetValue': 0,
#     'fields': {'TIMEOUTA': {'description': 'Bus timeout A',
#       'mask': 4095,
#       'access': 'read-write'},
#      'TIDLE': {'description': 'Idle clock timeout detection',
#       'mask': 4096,
#       'access': 'read-write'},
#      'TIMOUTEN': {'description': 'Clock timeout enable',
#       'mask': 32768,
#       'access': 'read-write'},
#      'TIMEOUTB': {'description': 'Bus timeout B',
#       'mask': 268369920,
#       'access': 'read-write'},
#      'TEXTEN': {'description': 'Extended clock timeout enable',
#       'mask': 2147483648,
#       'access': 'read-write'}}},
#    'ISR': {'description': 'Interrupt and Status register',
#     'addressOffset': 24,
#     'resetValue': 1,
#     'fields': {'ADDCODE': {'description': 'Address match code (Slave mode)',
#       'mask': 16646144,
#       'access': 'read-only'},
#      'DIR': {'description': 'Transfer direction (Slave mode)',
#       'mask': 65536,
#       'access': 'read-only'},
#      'BUSY': {'description': 'Bus busy', 'mask': 32768, 'access': 'read-only'},
#      'ALERT': {'description': 'SMBus alert',
#       'mask': 8192,
#       'access': 'read-only'},
#      'TIMEOUT': {'description': 'Timeout or t_low detection flag',
#       'mask': 4096,
#       'access': 'read-only'},
#      'PECERR': {'description': 'PEC Error in reception',
#       'mask': 2048,
#       'access': 'read-only'},
#      'OVR': {'description': 'Overrun/Underrun (slave mode)',
#       'mask': 1024,
#       'access': 'read-only'},
#      'ARLO': {'description': 'Arbitration lost',
#       'mask': 512,
#       'access': 'read-only'},
#      'BERR': {'description': 'Bus error', 'mask': 256, 'access': 'read-only'},
#      'TCR': {'description': 'Transfer Complete Reload',
#       'mask': 128,
#       'access': 'read-only'},
#      'TC': {'description': 'Transfer Complete (master mode)',
#       'mask': 64,
#       'access': 'read-only'},
#      'STOPF': {'description': 'Stop detection flag',
#       'mask': 32,
#       'access': 'read-only'},
#      'NACKF': {'description': 'Not acknowledge received flag',
#       'mask': 16,
#       'access': 'read-only'},
#      'ADDR': {'description': 'Address matched (slave mode)',
#       'mask': 8,
#       'access': 'read-only'},
#      'RXNE': {'description': 'Receive data register not empty (receivers)',
#       'mask': 4,
#       'access': 'read-only'},
#      'TXIS': {'description': 'Transmit interrupt status (transmitters)',
#       'mask': 2,
#       'access': 'read-write'},
#      'TXE': {'description': 'Transmit data register empty (transmitters)',
#       'mask': 1,
#       'access': 'read-write'}}},
#    'ICR': {'description': 'Interrupt clear register',
#     'addressOffset': 28,
#     'resetValue': 0,
#     'fields': {'ALERTCF': {'description': 'Alert flag clear',
#       'mask': 8192,
#       'access': 'write-only'},
#      'TIMOUTCF': {'description': 'Timeout detection flag clear',
#       'mask': 4096,
#       'access': 'write-only'},
#      'PECCF': {'description': 'PEC Error flag clear',
#       'mask': 2048,
#       'access': 'write-only'},
#      'OVRCF': {'description': 'Overrun/Underrun flag clear',
#       'mask': 1024,
#       'access': 'write-only'},
#      'ARLOCF': {'description': 'Arbitration lost flag clear',
#       'mask': 512,
#       'access': 'write-only'},
#      'BERRCF': {'description': 'Bus error flag clear',
#       'mask': 256,
#       'access': 'write-only'},
#      'STOPCF': {'description': 'Stop detection flag clear',
#       'mask': 32,
#       'access': 'write-only'},
#      'NACKCF': {'description': 'Not Acknowledge flag clear',
#       'mask': 16,
#       'access': 'write-only'},
#      'ADDRCF': {'description': 'Address Matched flag clear',
#       'mask': 8,
#       'access': 'write-only'}}},
#    'PECR': {'description': 'PEC register',
#     'addressOffset': 32,
#     'resetValue': 0,
#     'fields': {'PEC': {'description': 'Packet error checking register',
#       'mask': 255,
#       'access': 'read-only'}}},
#    'RXDR': {'description': 'Receive data register',
#     'addressOffset': 36,
#     'resetValue': 0,
#     'fields': {'RXDATA': {'description': '8-bit receive data',
#       'mask': 255,
#       'access': 'read-only'}}},
#    'TXDR': {'description': 'Transmit data register',
#     'addressOffset': 40,
#     'resetValue': 0,
#     'fields': {'TXDATA': {'description': '8-bit transmit data',
#       'mask': 255,
#       'access': 'read-write'}}}}},
#  'I2C2': {'address': 1073764352, 'base': 'I2C1'},
#  'I2C3': {'address': 1073772544, 'base': 'I2C1'},
#  'I2C4': {'address': 1073775616, 'base': 'I2C1'},
#  'FLASH': {'address': 1073881088,
#   'description': 'Flash',
#   'registers': {'ACR': {'description': 'Access control register',
#     'addressOffset': 0,
#     'resetValue': 1536,
#     'fields': {'LATENCY': {'description': 'Latency',
#       'mask': 15,
#       'access': 'read-write'},
#      'PRFTEN': {'description': 'Prefetch enable',
#       'mask': 256,
#       'access': 'read-write'},
#      'ICEN': {'description': 'Instruction cache enable',
#       'mask': 512,
#       'access': 'read-write'},
#      'DCEN': {'description': 'Data cache enable',
#       'mask': 1024,
#       'access': 'read-write'},
#      'ICRST': {'description': 'Instruction cache reset',
#       'mask': 2048,
#       'access': 'read-write'},
#      'DCRST': {'description': 'Data cache reset',
#       'mask': 4096,
#       'access': 'read-write'},
#      'RUN_PD': {'description': 'Flash Power-down mode during Low-power run mode',
#       'mask': 8192,
#       'access': 'read-write'},
#      'SLEEP_PD': {'description': 'Flash Power-down mode during Low-power sleep mode',
#       'mask': 16384,
#       'access': 'read-write'},
#      'DBG_SWEN': {'description': 'Debug software enable',
#       'mask': 262144,
#       'access': 'read-write'}}},
#    'PDKEYR': {'description': 'Power down key register',
#     'addressOffset': 4,
#     'resetValue': 0,
#     'fields': {'PDKEYR': {'description': 'RUN_PD in FLASH_ACR key',
#       'mask': 4294967295,
#       'access': 'write-only'}}},
#    'KEYR': {'description': 'Flash key register',
#     'addressOffset': 8,
#     'resetValue': 0,
#     'fields': {'KEYR': {'description': 'KEYR',
#       'mask': 4294967295,
#       'access': 'write-only'}}},
#    'OPTKEYR': {'description': 'Option byte key register',
#     'addressOffset': 12,
#     'resetValue': 0,
#     'fields': {'OPTKEYR': {'description': 'Option byte key',
#       'mask': 4294967295,
#       'access': 'write-only'}}},
#    'SR': {'description': 'Status register',
#     'addressOffset': 16,
#     'resetValue': 0,
#     'fields': {'EOP': {'description': 'End of operation',
#       'mask': 1,
#       'access': 'read-write'},
#      'OPERR': {'description': 'Operation error',
#       'mask': 2,
#       'access': 'read-write'},
#      'PROGERR': {'description': 'Programming error',
#       'mask': 8,
#       'access': 'read-write'},
#      'WRPERR': {'description': 'Write protected error',
#       'mask': 16,
#       'access': 'read-write'},
#      'PGAERR': {'description': 'Programming alignment error',
#       'mask': 32,
#       'access': 'read-write'},
#      'SIZERR': {'description': 'Size error',
#       'mask': 64,
#       'access': 'read-write'},
#      'PGSERR': {'description': 'Programming sequence error',
#       'mask': 128,
#       'access': 'read-write'},
#      'MISERR': {'description': 'Fast programming data miss error',
#       'mask': 256,
#       'access': 'read-write'},
#      'FASTERR': {'description': 'Fast programming error',
#       'mask': 512,
#       'access': 'read-write'},
#      'RDERR': {'description': 'PCROP read error',
#       'mask': 16384,
#       'access': 'read-write'},
#      'OPTVERR': {'description': 'Option validity error',
#       'mask': 32768,
#       'access': 'read-write'},
#      'BSY': {'description': 'Busy', 'mask': 65536, 'access': 'read-only'}}},
#    'CR': {'description': 'Flash control register',
#     'addressOffset': 20,
#     'resetValue': 3221225472,
#     'fields': {'PG': {'description': 'Programming',
#       'mask': 1,
#       'access': 'read-write'},
#      'PER': {'description': 'Page erase', 'mask': 2, 'access': 'read-write'},
#      'MER1': {'description': 'Bank 1 Mass erase',
#       'mask': 4,
#       'access': 'read-write'},
#      'PNB': {'description': 'Page number',
#       'mask': 1016,
#       'access': 'read-write'},
#      'STRT': {'description': 'Start', 'mask': 65536, 'access': 'read-write'},
#      'OPTSTRT': {'description': 'Options modification start',
#       'mask': 131072,
#       'access': 'read-write'},
#      'FSTPG': {'description': 'Fast programming',
#       'mask': 262144,
#       'access': 'read-write'},
#      'EOPIE': {'description': 'End of operation interrupt enable',
#       'mask': 16777216,
#       'access': 'read-write'},
#      'ERRIE': {'description': 'Error interrupt enable',
#       'mask': 33554432,
#       'access': 'read-write'},
#      'RDERRIE': {'description': 'PCROP read error interrupt enable',
#       'mask': 67108864,
#       'access': 'read-write'},
#      'OBL_LAUNCH': {'description': 'Force the option byte loading',
#       'mask': 134217728,
#       'access': 'read-write'},
#      'SEC_PROT1': {'description': 'SEC_PROT1',
#       'mask': 268435456,
#       'access': 'read-write'},
#      'OPTLOCK': {'description': 'Options Lock',
#       'mask': 1073741824,
#       'access': 'read-write'},
#      'LOCK': {'description': 'FLASH_CR Lock',
#       'mask': 2147483648,
#       'access': 'read-write'}}},
#    'ECCR': {'description': 'Flash ECC register',
#     'addressOffset': 24,
#     'resetValue': 0,
#     'fields': {'ADDR_ECC': {'description': 'ECC fail address',
#       'mask': 524287,
#       'access': 'read-only'},
#      'BK_ECC': {'description': 'BK_ECC',
#       'mask': 2097152,
#       'access': 'read-only'},
#      'SYSF_ECC': {'description': 'SYSF_ECC',
#       'mask': 4194304,
#       'access': 'read-only'},
#      'ECCIE': {'description': 'ECCIE',
#       'mask': 16777216,
#       'access': 'read-write'},
#      'ECCC2': {'description': 'ECC correction',
#       'mask': 268435456,
#       'access': 'read-write'},
#      'ECCD2': {'description': 'ECC2 detection',
#       'mask': 536870912,
#       'access': 'read-write'},
#      'ECCC': {'description': 'ECC correction',
#       'mask': 1073741824,
#       'access': 'read-write'},
#      'ECCD': {'description': 'ECC detection',
#       'mask': 2147483648,
#       'access': 'read-write'}}},
#    'OPTR': {'description': 'Flash option register',
#     'addressOffset': 32,
#     'resetValue': 4026531840,
#     'fields': {'RDP': {'description': 'Read protection level',
#       'mask': 255,
#       'access': 'read-write'},
#      'BOR_LEV': {'description': 'BOR reset Level',
#       'mask': 1792,
#       'access': 'read-write'},
#      'nRST_STOP': {'description': 'nRST_STOP',
#       'mask': 4096,
#       'access': 'read-write'},
#      'nRST_STDBY': {'description': 'nRST_STDBY',
#       'mask': 8192,
#       'access': 'read-write'},
#      'nRST_SHDW': {'description': 'nRST_SHDW',
#       'mask': 16384,
#       'access': 'read-write'},
#      'IDWG_SW': {'description': 'Independent watchdog selection',
#       'mask': 65536,
#       'access': 'read-write'},
#      'IWDG_STOP': {'description': 'Independent watchdog counter freeze in Stop mode',
#       'mask': 131072,
#       'access': 'read-write'},
#      'IWDG_STDBY': {'description': 'Independent watchdog counter freeze in Standby mode',
#       'mask': 262144,
#       'access': 'read-write'},
#      'WWDG_SW': {'description': 'Window watchdog selection',
#       'mask': 524288,
#       'access': 'read-write'},
#      'nBOOT1': {'description': 'Boot configuration',
#       'mask': 8388608,
#       'access': 'read-write'},
#      'SRAM2_PE': {'description': 'SRAM2 parity check enable',
#       'mask': 16777216,
#       'access': 'read-write'},
#      'SRAM2_RST': {'description': 'SRAM2 Erase when system reset',
#       'mask': 33554432,
#       'access': 'read-write'},
#      'nSWBOOT0': {'description': 'nSWBOOT0',
#       'mask': 67108864,
#       'access': 'read-write'},
#      'nBOOT0': {'description': 'nBOOT0',
#       'mask': 134217728,
#       'access': 'read-write'},
#      'NRST_MODE': {'description': 'NRST_MODE',
#       'mask': 805306368,
#       'access': 'read-write'},
#      'IRHEN': {'description': 'IRHEN',
#       'mask': 1073741824,
#       'access': 'read-write'}}},
#    'PCROP1SR': {'description': 'Flash Bank 1 PCROP Start address register',
#     'addressOffset': 36,
#     'resetValue': 4294901760,
#     'fields': {'PCROP1_STRT': {'description': 'Bank 1 PCROP area start offset',
#       'mask': 32767,
#       'access': 'read-write'}}},
#    'PCROP1ER': {'description': 'Flash Bank 1 PCROP End address register',
#     'addressOffset': 40,
#     'resetValue': 268369920,
#     'fields': {'PCROP1_END': {'description': 'Bank 1 PCROP area end offset',
#       'mask': 32767,
#       'access': 'read-write'},
#      'PCROP_RDP': {'description': 'PCROP area preserved when RDP level decreased',
#       'mask': 2147483648,
#       'access': 'read-write'}}},
#    'WRP1AR': {'description': 'Flash Bank 1 WRP area A address register',
#     'addressOffset': 44,
#     'resetValue': 0,
#     'fields': {'WRP1A_STRT': {'description': 'Bank 1 WRP first area start offset',
#       'mask': 127,
#       'access': 'read-write'},
#      'WRP1A_END': {'description': 'Bank 1 WRP first area A end offset',
#       'mask': 8323072,
#       'access': 'read-write'}}},
#    'WRP1BR': {'description': 'Flash Bank 1 WRP area B address register',
#     'addressOffset': 48,
#     'resetValue': 0,
#     'fields': {'WRP1B_STRT': {'description': 'Bank 1 WRP second area B end offset',
#       'mask': 127,
#       'access': 'read-write'},
#      'WRP1B_END': {'description': 'Bank 1 WRP second area B start offset',
#       'mask': 8323072,
#       'access': 'read-write'}}},
#    'SEC1R': {'description': 'securable area bank1 register',
#     'addressOffset': 112,
#     'resetValue': 4278255360,
#     'fields': {'BOOT_LOCK': {'description': 'BOOT_LOCK',
#       'mask': 65536,
#       'access': 'read-write'},
#      'SEC_SIZE1': {'description': 'SEC_SIZE1',
#       'mask': 127,
#       'access': 'read-write'}}}}},
#  'DBGMCU': {'address': 3758366720,
#   'description': 'Debug support',
#   'registers': {'IDCODE': {'description': 'MCU Device ID Code Register',
#     'addressOffset': 0,
#     'resetValue': 0,
#     'fields': {'DEV_ID': {'description': 'Device Identifier',
#       'mask': 65535,
#       'access': 'read-only'},
#      'REV_ID': {'description': 'Revision Identifier',
#       'mask': 4294901760,
#       'access': 'read-only'}}},
#    'CR': {'description': 'Debug MCU Configuration Register',
#     'addressOffset': 4,
#     'resetValue': 0,
#     'fields': {'DBG_SLEEP': {'description': 'Debug Sleep Mode',
#       'mask': 1,
#       'access': 'read-write'},
#      'DBG_STOP': {'description': 'Debug Stop Mode',
#       'mask': 2,
#       'access': 'read-write'},
#      'DBG_STANDBY': {'description': 'Debug Standby Mode',
#       'mask': 4,
#       'access': 'read-write'},
#      'TRACE_IOEN': {'description': 'Trace pin assignment control',
#       'mask': 32,
#       'access': 'read-write'},
#      'TRACE_MODE': {'description': 'Trace pin assignment control',
#       'mask': 192,
#       'access': 'read-write'}}},
#    'APB1L_FZ': {'description': 'APB Low Freeze Register 1',
#     'addressOffset': 8,
#     'resetValue': 0,
#     'fields': {'DBG_TIMER2_STOP': {'description': 'Debug Timer 2 stopped when Core is halted',
#       'mask': 1,
#       'access': 'read-write'},
#      'DBG_TIM3_STOP': {'description': 'TIM3 counter stopped when core is halted',
#       'mask': 2,
#       'access': 'read-write'},
#      'DBG_TIM4_STOP': {'description': 'TIM4 counter stopped when core is halted',
#       'mask': 4,
#       'access': 'read-write'},
#      'DBG_TIM5_STOP': {'description': 'TIM5 counter stopped when core is halted',
#       'mask': 8,
#       'access': 'read-write'},
#      'DBG_TIMER6_STOP': {'description': 'Debug Timer 6 stopped when Core is halted',
#       'mask': 16,
#       'access': 'read-write'},
#      'DBG_TIM7_STOP': {'description': 'TIM7 counter stopped when core is halted',
#       'mask': 32,
#       'access': 'read-write'},
#      'DBG_RTC_STOP': {'description': 'Debug RTC stopped when Core is halted',
#       'mask': 1024,
#       'access': 'read-write'},
#      'DBG_WWDG_STOP': {'description': 'Debug Window Wachdog stopped when Core is halted',
#       'mask': 2048,
#       'access': 'read-write'},
#      'DBG_IWDG_STOP': {'description': 'Debug Independent Wachdog stopped when Core is halted',
#       'mask': 4096,
#       'access': 'read-write'},
#      'DBG_I2C1_STOP': {'description': 'I2C1 SMBUS timeout mode stopped when core is halted',
#       'mask': 2097152,
#       'access': 'read-write'},
#      'DBG_I2C2_STOP': {'description': 'I2C2 SMBUS timeout mode stopped when core is halted',
#       'mask': 4194304,
#       'access': 'read-write'},
#      'DBG_I2C3_STOP': {'description': 'I2C3 SMBUS timeout mode stopped when core is halted',
#       'mask': 1073741824,
#       'access': 'read-write'},
#      'DBG_LPTIMER_STOP': {'description': 'LPTIM1 counter stopped when core is halted',
#       'mask': 2147483648,
#       'access': 'read-write'}}},
#    'APB1H_FZ': {'description': 'APB Low Freeze Register 2',
#     'addressOffset': 12,
#     'resetValue': 0,
#     'fields': {'DBG_I2C4_STOP': {'description': 'DBG_I2C4_STOP',
#       'mask': 2,
#       'access': 'read-write'}}},
#    'APB2_FZ': {'description': 'APB High Freeze Register',
#     'addressOffset': 16,
#     'resetValue': 0,
#     'fields': {'DBG_TIM1_STOP': {'description': 'TIM1 counter stopped when core is halted',
#       'mask': 2048,
#       'access': 'read-write'},
#      'DBG_TIM8_STOP': {'description': 'TIM8 counter stopped when core is halted',
#       'mask': 8192,
#       'access': 'read-write'},
#      'DBG_TIM15_STOP': {'description': 'TIM15 counter stopped when core is halted',
#       'mask': 65536,
#       'access': 'read-write'},
#      'DBG_TIM16_STOP': {'description': 'TIM16 counter stopped when core is halted',
#       'mask': 131072,
#       'access': 'read-write'},
#      'DBG_TIM17_STOP': {'description': 'TIM17 counter stopped when core is halted',
#       'mask': 262144,
#       'access': 'read-write'},
#      'DBG_TIM20_STOP': {'description': 'TIM20counter stopped when core is halted',
#       'mask': 1048576,
#       'access': 'read-write'},
#      'DBG_HRTIM0_STOP': {'description': 'DBG_HRTIM0_STOP',
#       'mask': 67108864,
#       'access': 'read-write'},
#      'DBG_HRTIM1_STOP': {'description': 'DBG_HRTIM0_STOP',
#       'mask': 134217728,
#       'access': 'read-write'},
#      'DBG_HRTIM2_STOP': {'description': 'DBG_HRTIM0_STOP',
#       'mask': 268435456,
#       'access': 'read-write'},
#      'DBG_HRTIM3_STOP': {'description': 'DBG_HRTIM0_STOP',
#       'mask': 536870912,
#       'access': 'read-write'}}}}},
#  'RCC': {'address': 1073876992,
#   'description': 'Reset and clock control',
#   'registers': {'CR': {'description': 'Clock control register',
#     'addressOffset': 0,
#     'resetValue': 99,
#     'fields': {'HSION': {'description': 'HSI16 clock enable. Set and cleared by software. Cleared by hardware to stop the HSI16 oscillator when entering Stop, Standby or Shutdown mode. Set by hardware to force the HSI16 oscillator ON when STOPWUCK=1 or HSIASFS = 1 when leaving Stop modes, or in case of failure of the HSE crystal oscillator. This bit is set by hardware if the HSI16 is used directly or indirectly as system clock.',
#       'mask': 256,
#       'access': 'read-write'},
#      'HSIKERON': {'description': 'HSI16 always enable for peripheral kernels.. Set and cleared by software to force HSI16 ON even in Stop modes. The HSI16 can only feed USARTs and I<sup>2</sup>Cs peripherals configured with HSI16 as kernel clock. Keeping the HSI16 ON in Stop mode allows to avoid slowing down the communication speed because of the HSI16 startup time. This bit has no effect on HSION value.',
#       'mask': 512,
#       'access': 'read-write'},
#      'HSIRDY': {'description': 'HSI16 clock ready flag. Set by hardware to indicate that HSI16 oscillator is stable. This bit is set only when HSI16 is enabled by software by setting HSION. Note: Once the HSION bit is cleared, HSIRDY goes low after 6 HSI16 clock cycles.',
#       'mask': 1024,
#       'access': 'read-only'},
#      'HSEON': {'description': 'HSE clock enable. Set and cleared by software. Cleared by hardware to stop the HSE oscillator when entering Stop, Standby or Shutdown mode. This bit cannot be reset if the HSE oscillator is used directly or indirectly as the system clock.',
#       'mask': 65536,
#       'access': 'read-write'},
#      'HSERDY': {'description': 'HSE clock ready flag. Set by hardware to indicate that the HSE oscillator is stable. Note: Once the HSEON bit is cleared, HSERDY goes low after 6 HSE clock cycles.',
#       'mask': 131072,
#       'access': 'read-only'},
#      'HSEBYP': {'description': 'HSE crystal oscillator bypass. Set and cleared by software to bypass the oscillator with an external clock. The external clock must be enabled with the HSEON bit set, to be used by the device. The HSEBYP bit can be written only if the HSE oscillator is disabled.',
#       'mask': 262144,
#       'access': 'read-write'},
#      'CSSON': {'description': 'Clock security system enable. Set by software to enable the clock security system. When CSSON is set, the clock detector is enabled by hardware when the HSE oscillator is ready, and disabled by hardware if a HSE clock failure is detected. This bit is set only and is cleared by reset.',
#       'mask': 524288,
#       'access': 'read-write'},
#      'PLLON': {'description': 'Main PLL enable. Set and cleared by software to enable the main PLL. Cleared by hardware when entering Stop, Standby or Shutdown mode. This bit cannot be reset if the PLL clock is used as the system clock.',
#       'mask': 16777216,
#       'access': 'read-write'},
#      'PLLRDY': {'description': 'Main PLL clock ready flag. Set by hardware to indicate that the main PLL is locked.',
#       'mask': 33554432,
#       'access': 'read-only'}}},
#    'ICSCR': {'description': 'Internal clock sources calibration register',
#     'addressOffset': 4,
#     'resetValue': 1073741824,
#     'fields': {'HSICAL': {'description': 'HSI16 clock calibration. These bits are initialized at startup with the factory-programmed HSI16 calibration trim value. When HSITRIM is written, HSICAL is updated with the sum of HSITRIM and the factory trim value.',
#       'mask': 16711680,
#       'access': 'read-only'},
#      'HSITRIM': {'description': 'HSI16 clock trimming. These bits provide an additional user-programmable trimming value that is added to the HSICAL[7:0] bits. It can be programmed to adjust to variations in voltage and temperature that influence the frequency of the HSI16. The default value is 16, which, when added to the HSICAL value, should trim the HSI16 to 16 MHz 1 %.',
#       'mask': 2130706432,
#       'access': 'read-write'}}},
#    'CFGR': {'description': 'Clock configuration register',
#     'addressOffset': 8,
#     'resetValue': 5,
#     'fields': {'SW': {'description': 'System clock switch. Set and cleared by software to select system clock source (SYSCLK). Configured by hardware to force HSI16 oscillator selection when exiting stop and standby modes or in case of failure of the HSE oscillator.',
#       'mask': 3,
#       'access': 'read-write'},
#      'SWS': {'description': 'System clock switch status. Set and cleared by hardware to indicate which clock source is used as system clock.',
#       'mask': 12,
#       'access': 'read-only'},
#      'HPRE': {'description': 'AHB prescaler. Set and cleared by software to control the division factor of the AHB clock. Note: Depending on the device voltage range, the software has to set correctly these bits to ensure that the system frequency does not exceed the maximum allowed frequency (for more details please refer to Section 6.1.5: Dynamic voltage scaling management). After a write operation to these bits and before decreasing the voltage range, this register must be read to be sure that the new value has been taken into account. 0xxx: SYSCLK not divided',
#       'mask': 240,
#       'access': 'read-write'},
#      'PPRE1': {'description': 'APB1 prescaler. Set and cleared by software to control the division factor of the APB1 clock (PCLK1). 0xx: HCLK not divided',
#       'mask': 1792,
#       'access': 'read-write'},
#      'PPRE2': {'description': 'APB2 prescaler. Set and cleared by software to control the division factor of the APB2 clock (PCLK2). 0xx: HCLK not divided',
#       'mask': 14336,
#       'access': 'read-write'},
#      'MCOSEL': {'description': 'Microcontroller clock output . Set and cleared by software. Others: Reserved Note: This clock output may have some truncated cycles at startup or during MCO clock source switching.',
#       'mask': 251658240,
#       'access': 'read-write'},
#      'MCOPRE': {'description': 'Microcontroller clock output prescaler. These bits are set and cleared by software. It is highly recommended to change this prescaler before MCO output is enabled. Others: not allowed',
#       'mask': 1879048192,
#       'access': 'read-write'}}},
#    'PLLCFGR': {'description': 'PLL configuration register',
#     'addressOffset': 12,
#     'resetValue': 4096,
#     'fields': {'PLLSRC': {'description': 'Main PLL entry clock source. Set and cleared by software to select PLL clock source. These bits can be written only when PLL is disabled. In order to save power, when no PLL is used, the value of PLLSRC should be 00.',
#       'mask': 3,
#       'access': 'read-write'},
#      'PLLM': {'description': 'Division factor for the main PLL input clock. Set and cleared by software to divide the PLL input clock before the VCO. These bits can be written only when all PLLs are disabled. VCO input frequency = PLL input clock frequency / PLLM with 1 <= PLLM <= 16 ... Note: The software has to set these bits correctly to ensure that the VCO input frequency is within the range defined in the device datasheet.',
#       'mask': 240,
#       'access': 'read-write'},
#      'PLLN': {'description': 'Main PLL multiplication factor for VCO. Set and cleared by software to control the multiplication factor of the VCO. These bits can be written only when the PLL is disabled. VCO output frequency = VCO input frequency x PLLN with 8 =< PLLN =< 127 ... ... Note: The software has to set correctly these bits to assure that the VCO output frequency is within the range defined in the device datasheet.',
#       'mask': 32512,
#       'access': 'read-write'},
#      'PLLPEN': {'description': 'Main PLL PLL P clock output enable. Set and reset by software to enable the PLL P clock output of the PLL. In order to save power, when the PLL P clock output of the PLL is not used, the value of PLLPEN should be 0.',
#       'mask': 65536,
#       'access': 'read-write'},
#      'PLLP': {'description': 'Main PLL division factor for PLL P clock.. Set and cleared by software to control the frequency of the main PLL output clock PLL P clock. These bits can be written only if PLL is disabled. When the PLLPDIV[4:0] is set to 00000PLL P output clock frequency = VCO frequency / PLLP with PLLP =7, or 17 Note: The software has to set these bits correctly not to exceed 170 MHz on this domain.',
#       'mask': 131072,
#       'access': 'read-write'},
#      'PLLQEN': {'description': 'Main PLL Q clock output enable. Set and reset by software to enable the PLL Q clock output of the PLL. In order to save power, when the PLL Q clock output of the PLL is not used, the value of PLLQEN should be 0.',
#       'mask': 1048576,
#       'access': 'read-write'},
#      'PLLQ': {'description': 'Main PLL division factor for PLL Q clock.. Set and cleared by software to control the frequency of the main PLL output clock PLL Q clock. This output can be selected for USB, RNG, SAI (48 MHz clock). These bits can be written only if PLL is disabled. PLL Q output clock frequency = VCO frequency / PLLQ with PLLQ = 2, 4, 6, or 8 Note: The software has to set these bits correctly not to exceed 170 MHz on this domain.',
#       'mask': 6291456,
#       'access': 'read-write'},
#      'PLLREN': {'description': 'PLL R clock output enable. Set and reset by software to enable the PLL R clock output of the PLL (used as system clock). This bit cannot be written when PLL R clock output of the PLL is used as System Clock. In order to save power, when the PLL R clock output of the PLL is not used, the value of PLLREN should be 0.',
#       'mask': 16777216,
#       'access': 'read-write'},
#      'PLLR': {'description': 'Main PLL division factor for PLL R clock (system clock). Set and cleared by software to control the frequency of the main PLL output clock PLLCLK. This output can be selected as system clock. These bits can be written only if PLL is disabled. PLL R output clock frequency = VCO frequency / PLLR with PLLR = 2, 4, 6, or 8 Note: The software has to set these bits correctly not to exceed 170 MHz on this domain.',
#       'mask': 100663296,
#       'access': 'read-write'},
#      'PLLPDIV': {'description': 'Main PLLP division factor. Set and cleared by software to control the PLL P frequency. PLL P output clock frequency = VCO frequency / PLLPDIV. ....',
#       'mask': 4160749568,
#       'access': 'read-write'}}},
#    'CIER': {'description': 'Clock interrupt enable register',
#     'addressOffset': 24,
#     'resetValue': 0,
#     'fields': {'LSIRDYIE': {'description': 'LSI ready interrupt enable. Set and cleared by software to enable/disable interrupt caused by the LSI oscillator stabilization.',
#       'mask': 1,
#       'access': 'read-write'},
#      'LSERDYIE': {'description': 'LSE ready interrupt enable. Set and cleared by software to enable/disable interrupt caused by the LSE oscillator stabilization.',
#       'mask': 2,
#       'access': 'read-write'},
#      'HSIRDYIE': {'description': 'HSI16 ready interrupt enable. Set and cleared by software to enable/disable interrupt caused by the HSI16 oscillator stabilization.',
#       'mask': 8,
#       'access': 'read-write'},
#      'HSERDYIE': {'description': 'HSE ready interrupt enable. Set and cleared by software to enable/disable interrupt caused by the HSE oscillator stabilization.',
#       'mask': 16,
#       'access': 'read-write'},
#      'PLLRDYIE': {'description': 'PLL ready interrupt enable. Set and cleared by software to enable/disable interrupt caused by PLL lock.',
#       'mask': 32,
#       'access': 'read-write'},
#      'LSECSSIE': {'description': 'LSE clock security system interrupt enable. Set and cleared by software to enable/disable interrupt caused by the clock security system on LSE.',
#       'mask': 512,
#       'access': 'read-write'},
#      'HSI48RDYIE': {'description': 'HSI48 ready interrupt enable . Set and cleared by software to enable/disable interrupt caused by the internal HSI48 oscillator.',
#       'mask': 1024,
#       'access': 'read-write'}}},
#    'CIFR': {'description': 'Clock interrupt flag register',
#     'addressOffset': 28,
#     'resetValue': 0,
#     'fields': {'LSIRDYF': {'description': 'LSI ready interrupt flag. Set by hardware when the LSI clock becomes stable and LSIRDYDIE is set. Cleared by software setting the LSIRDYC bit.',
#       'mask': 1,
#       'access': 'read-only'},
#      'LSERDYF': {'description': 'LSE ready interrupt flag. Set by hardware when the LSE clock becomes stable and LSERDYDIE is set. Cleared by software setting the LSERDYC bit.',
#       'mask': 2,
#       'access': 'read-only'},
#      'HSIRDYF': {'description': 'HSI16 ready interrupt flag. Set by hardware when the HSI16 clock becomes stable and HSIRDYDIE is set in a response to setting the HSION (refer to Clock control register (RCC_CR)). When HSION is not set but the HSI16 oscillator is enabled by the peripheral through a clock request, this bit is not set and no interrupt is generated. Cleared by software setting the HSIRDYC bit.',
#       'mask': 8,
#       'access': 'read-only'},
#      'HSERDYF': {'description': 'HSE ready interrupt flag. Set by hardware when the HSE clock becomes stable and HSERDYDIE is set. Cleared by software setting the HSERDYC bit.',
#       'mask': 16,
#       'access': 'read-only'},
#      'PLLRDYF': {'description': 'PLL ready interrupt flag. Set by hardware when the PLL locks and PLLRDYDIE is set. Cleared by software setting the PLLRDYC bit.',
#       'mask': 32,
#       'access': 'read-only'},
#      'CSSF': {'description': 'Clock security system interrupt flag. Set by hardware when a failure is detected in the HSE oscillator. Cleared by software setting the CSSC bit.',
#       'mask': 256,
#       'access': 'read-only'},
#      'LSECSSF': {'description': 'LSE Clock security system interrupt flag. Set by hardware when a failure is detected in the LSE oscillator. Cleared by software setting the LSECSSC bit.',
#       'mask': 512,
#       'access': 'read-only'},
#      'HSI48RDYF': {'description': 'HSI48 ready interrupt flag . Set by hardware when the HSI48 clock becomes stable and HSI48RDYIE is set in a response to setting the HSI48ON (refer to Clock recovery RC register (RCC_CRRCR)). Cleared by software setting the HSI48RDYC bit.',
#       'mask': 1024,
#       'access': 'read-only'}}},
#    'CICR': {'description': 'Clock interrupt clear register',
#     'addressOffset': 32,
#     'resetValue': 0,
#     'fields': {'LSIRDYC': {'description': 'LSI ready interrupt clear. This bit is set by software to clear the LSIRDYF flag.',
#       'mask': 1,
#       'access': 'write-only'},
#      'LSERDYC': {'description': 'LSE ready interrupt clear. This bit is set by software to clear the LSERDYF flag.',
#       'mask': 2,
#       'access': 'write-only'},
#      'HSIRDYC': {'description': 'HSI16 ready interrupt clear. This bit is set software to clear the HSIRDYF flag.',
#       'mask': 8,
#       'access': 'write-only'},
#      'HSERDYC': {'description': 'HSE ready interrupt clear. This bit is set by software to clear the HSERDYF flag.',
#       'mask': 16,
#       'access': 'write-only'},
#      'PLLRDYC': {'description': 'PLL ready interrupt clear. This bit is set by software to clear the PLLRDYF flag.',
#       'mask': 32,
#       'access': 'write-only'},
#      'CSSC': {'description': 'Clock security system interrupt clear. This bit is set by software to clear the CSSF flag.',
#       'mask': 256,
#       'access': 'write-only'},
#      'LSECSSC': {'description': 'LSE Clock security system interrupt clear. This bit is set by software to clear the LSECSSF flag.',
#       'mask': 512,
#       'access': 'write-only'},
#      'HSI48RDYC': {'description': 'HSI48 oscillator ready interrupt clear . This bit is set by software to clear the HSI48RDYF flag.',
#       'mask': 1024,
#       'access': 'write-only'}}},
#    'AHB1RSTR': {'description': 'AHB1 peripheral reset register',
#     'addressOffset': 40,
#     'resetValue': 0,
#     'fields': {'DMA1RST': {'description': 'DMA1 reset. Set and cleared by software.',
#       'mask': 1,
#       'access': 'read-write'},
#      'DMA2RST': {'description': 'DMA2 reset. Set and cleared by software.',
#       'mask': 2,
#       'access': 'read-write'},
#      'DMAMUX1RST': {'description': 'Set and cleared by software.',
#       'mask': 4,
#       'access': 'read-write'},
#      'CORDICRST': {'description': 'Set and cleared by software',
#       'mask': 8,
#       'access': 'read-write'},
#      'FMACRST': {'description': 'Set and cleared by software',
#       'mask': 16,
#       'access': 'read-write'},
#      'FLASHRST': {'description': 'Flash memory interface reset. Set and cleared by software. This bit can be activated only when the Flash memory is in power down mode.',
#       'mask': 256,
#       'access': 'read-write'},
#      'CRCRST': {'description': 'CRC reset. Set and cleared by software.',
#       'mask': 4096,
#       'access': 'read-write'}}},
#    'AHB2RSTR': {'description': 'AHB2 peripheral reset register',
#     'addressOffset': 44,
#     'resetValue': 0,
#     'fields': {'GPIOARST': {'description': 'IO port A reset. Set and cleared by software.',
#       'mask': 1,
#       'access': 'read-write'},
#      'GPIOBRST': {'description': 'IO port B reset. Set and cleared by software.',
#       'mask': 2,
#       'access': 'read-write'},
#      'GPIOCRST': {'description': 'IO port C reset. Set and cleared by software.',
#       'mask': 4,
#       'access': 'read-write'},
#      'GPIODRST': {'description': 'IO port D reset. Set and cleared by software.',
#       'mask': 8,
#       'access': 'read-write'},
#      'GPIOERST': {'description': 'IO port E reset. Set and cleared by software.',
#       'mask': 16,
#       'access': 'read-write'},
#      'GPIOFRST': {'description': 'IO port F reset. Set and cleared by software.',
#       'mask': 32,
#       'access': 'read-write'},
#      'GPIOGRST': {'description': 'IO port G reset. Set and cleared by software.',
#       'mask': 64,
#       'access': 'read-write'},
#      'ADC12RST': {'description': 'ADC12 reset. Set and cleared by software.',
#       'mask': 8192,
#       'access': 'read-write'},
#      'ADC345RST': {'description': 'ADC345 reset. Set and cleared by software.',
#       'mask': 16384,
#       'access': 'read-write'},
#      'DAC1RST': {'description': 'DAC1 reset. Set and cleared by software.',
#       'mask': 65536,
#       'access': 'read-write'},
#      'DAC2RST': {'description': 'DAC2 reset. Set and cleared by software.',
#       'mask': 131072,
#       'access': 'read-write'},
#      'DAC3RST': {'description': 'DAC3 reset. Set and cleared by software.',
#       'mask': 262144,
#       'access': 'read-write'},
#      'DAC4RST': {'description': 'DAC4 reset. Set and cleared by software.',
#       'mask': 524288,
#       'access': 'read-write'},
#      'AESRST': {'description': 'AESRST reset . Set and cleared by software.',
#       'mask': 16777216,
#       'access': 'read-write'},
#      'RNGRST': {'description': 'RNG reset. Set and cleared by software.',
#       'mask': 67108864,
#       'access': 'read-write'}}},
#    'AHB3RSTR': {'description': 'AHB3 peripheral reset register',
#     'addressOffset': 48,
#     'resetValue': 0,
#     'fields': {'FMCRST': {'description': 'Flexible static memory controller reset. Set and cleared by software.',
#       'mask': 1,
#       'access': 'read-write'},
#      'QSPIRST': {'description': 'QUADSPI reset. Set and cleared by software.',
#       'mask': 256,
#       'access': 'read-write'}}},
#    'APB1RSTR1': {'description': 'APB1 peripheral reset register 1',
#     'addressOffset': 56,
#     'resetValue': 0,
#     'fields': {'TIM2RST': {'description': 'TIM2 timer reset. Set and cleared by software.',
#       'mask': 1,
#       'access': 'read-write'},
#      'TIM3RST': {'description': 'TIM3 timer reset. Set and cleared by software.',
#       'mask': 2,
#       'access': 'read-write'},
#      'TIM4RST': {'description': 'TIM3 timer reset. Set and cleared by software.',
#       'mask': 4,
#       'access': 'read-write'},
#      'TIM5RST': {'description': 'TIM5 timer reset. Set and cleared by software.',
#       'mask': 8,
#       'access': 'read-write'},
#      'TIM6RST': {'description': 'TIM6 timer reset. Set and cleared by software.',
#       'mask': 16,
#       'access': 'read-write'},
#      'TIM7RST': {'description': 'TIM7 timer reset. Set and cleared by software.',
#       'mask': 32,
#       'access': 'read-write'},
#      'CRSRST': {'description': 'CRS reset. Set and cleared by software.',
#       'mask': 256,
#       'access': 'read-write'},
#      'SPI2RST': {'description': 'SPI2 reset. Set and cleared by software.',
#       'mask': 16384,
#       'access': 'read-write'},
# ...
#      'DTOG_TX': {'description': 'DTOG_TX', 'mask': 64, 'access': 'read-write'},
#      'CTR_TX': {'description': 'CTR_TX', 'mask': 128, 'access': 'read-write'},
#      'EP_KIND': {'description': 'EP_KIND',
#       'mask': 256,
#       'access': 'read-write'},
#      'EP_TYPE': {'description': 'EP_TYPE',
#       'mask': 1536,
#       'access': 'read-write'},
#      'SETUP': {'description': 'SETUP', 'mask': 2048, 'access': 'read-write'},
#      'STAT_RX': {'description': 'STAT_RX',
#       'mask': 12288,
#       'access': 'read-write'},
#      'DTOG_RX': {'description': 'DTOG_RX',
#       'mask': 16384,
#       'access': 'read-write'},
#      'CTR_RX': {'description': 'CTR_RX',
#       'mask': 32768,
#       'access': 'read-write'}}},
#    'EP5R': {'description': 'USB endpoint n register',
#     'addressOffset': 20,
#     'resetValue': 0,
#     'fields': {'EA': {'description': 'EA', 'mask': 15, 'access': 'read-write'},
#      'STAT_TX': {'description': 'STAT_TX', 'mask': 48, 'access': 'read-write'},
#      'DTOG_TX': {'description': 'DTOG_TX', 'mask': 64, 'access': 'read-write'},
#      'CTR_TX': {'description': 'CTR_TX', 'mask': 128, 'access': 'read-write'},
#      'EP_KIND': {'description': 'EP_KIND',
#       'mask': 256,
#       'access': 'read-write'},
#      'EP_TYPE': {'description': 'EP_TYPE',
#       'mask': 1536,
#       'access': 'read-write'},
#      'SETUP': {'description': 'SETUP', 'mask': 2048, 'access': 'read-write'},
#      'STAT_RX': {'description': 'STAT_RX',
#       'mask': 12288,
#       'access': 'read-write'},
#      'DTOG_RX': {'description': 'DTOG_RX',
#       'mask': 16384,
#       'access': 'read-write'},
#      'CTR_RX': {'description': 'CTR_RX',
#       'mask': 32768,
#       'access': 'read-write'}}},
#    'EP6R': {'description': 'USB endpoint n register',
#     'addressOffset': 24,
#     'resetValue': 0,
#     'fields': {'EA': {'description': 'EA', 'mask': 15, 'access': 'read-write'},
#      'STAT_TX': {'description': 'STAT_TX', 'mask': 48, 'access': 'read-write'},
#      'DTOG_TX': {'description': 'DTOG_TX', 'mask': 64, 'access': 'read-write'},
#      'CTR_TX': {'description': 'CTR_TX', 'mask': 128, 'access': 'read-write'},
#      'EP_KIND': {'description': 'EP_KIND',
#       'mask': 256,
#       'access': 'read-write'},
#      'EP_TYPE': {'description': 'EP_TYPE',
#       'mask': 1536,
#       'access': 'read-write'},
#      'SETUP': {'description': 'SETUP', 'mask': 2048, 'access': 'read-write'},
#      'STAT_RX': {'description': 'STAT_RX',
#       'mask': 12288,
#       'access': 'read-write'},
#      'DTOG_RX': {'description': 'DTOG_RX',
#       'mask': 16384,
#       'access': 'read-write'},
#      'CTR_RX': {'description': 'CTR_RX',
#       'mask': 32768,
#       'access': 'read-write'}}},
#    'EP7R': {'description': 'USB endpoint n register',
#     'addressOffset': 28,
#     'resetValue': 0,
#     'fields': {'EA': {'description': 'EA', 'mask': 15, 'access': 'read-write'},
#      'STAT_TX': {'description': 'STAT_TX', 'mask': 48, 'access': 'read-write'},
#      'DTOG_TX': {'description': 'DTOG_TX', 'mask': 64, 'access': 'read-write'},
#      'CTR_TX': {'description': 'CTR_TX', 'mask': 128, 'access': 'read-write'},
#      'EP_KIND': {'description': 'EP_KIND',
#       'mask': 256,
#       'access': 'read-write'},
#      'EP_TYPE': {'description': 'EP_TYPE',
#       'mask': 1536,
#       'access': 'read-write'},
#      'SETUP': {'description': 'SETUP', 'mask': 2048, 'access': 'read-write'},
#      'STAT_RX': {'description': 'STAT_RX',
#       'mask': 12288,
#       'access': 'read-write'},
#      'DTOG_RX': {'description': 'DTOG_RX',
#       'mask': 16384,
#       'access': 'read-write'},
#      'CTR_RX': {'description': 'CTR_RX',
#       'mask': 32768,
#       'access': 'read-write'}}},
#    'CNTR': {'description': 'USB control register',
#     'addressOffset': 64,
#     'resetValue': 0,
#     'fields': {'FRES': {'description': 'FRES',
#       'mask': 1,
#       'access': 'read-write'},
#      'PDWN': {'description': 'PDWN', 'mask': 2, 'access': 'read-write'},
#      'LP_MODE': {'description': 'LP_MODE', 'mask': 4, 'access': 'read-write'},
#      'FSUSP': {'description': 'FSUSP', 'mask': 8, 'access': 'read-write'},
#      'RESUME': {'description': 'RESUME', 'mask': 16, 'access': 'read-write'},
#      'L1RESUME': {'description': 'L1RESUME',
#       'mask': 32,
#       'access': 'read-write'},
#      'L1REQM': {'description': 'L1REQM', 'mask': 128, 'access': 'read-write'},
#      'ESOFM': {'description': 'ESOFM', 'mask': 256, 'access': 'read-write'},
#      'SOFM': {'description': 'SOFM', 'mask': 512, 'access': 'read-write'},
#      'RESETM': {'description': 'RESETM', 'mask': 1024, 'access': 'read-write'},
#      'SUSPM': {'description': 'SUSPM', 'mask': 2048, 'access': 'read-write'},
#      'WKUPM': {'description': 'WKUPM', 'mask': 4096, 'access': 'read-write'},
#      'ERRM': {'description': 'ERRM', 'mask': 8192, 'access': 'read-write'},
#      'PMAOVRM': {'description': 'PMAOVRM',
#       'mask': 16384,
#       'access': 'read-write'},
#      'CTRM': {'description': 'CTRM', 'mask': 32768, 'access': 'read-write'}}},
#    'ISTR': {'description': 'USB interrupt status register',
#     'addressOffset': 68,
#     'resetValue': 0,
#     'fields': {'EP_ID': {'description': 'EP_ID',
#       'mask': 15,
#       'access': 'read-write'},
#      'DIR': {'description': 'DIR', 'mask': 16, 'access': 'read-write'},
#      'L1REQ': {'description': 'L1REQ', 'mask': 128, 'access': 'read-write'},
#      'ESOF': {'description': 'ESOF', 'mask': 256, 'access': 'read-write'},
#      'SOF': {'description': 'SOF', 'mask': 512, 'access': 'read-write'},
#      'RESET': {'description': 'RESET', 'mask': 1024, 'access': 'read-write'},
#      'SUSP': {'description': 'SUSP', 'mask': 2048, 'access': 'read-write'},
#      'WKUP': {'description': 'WKUP', 'mask': 4096, 'access': 'read-write'},
#      'ERR': {'description': 'ERR', 'mask': 8192, 'access': 'read-write'},
#      'PMAOVR': {'description': 'PMAOVR',
#       'mask': 16384,
#       'access': 'read-write'},
#      'CTR': {'description': 'CTR', 'mask': 32768, 'access': 'read-write'}}},
#    'FNR': {'description': 'USB frame number register',
#     'addressOffset': 72,
#     'resetValue': 0,
#     'fields': {'FN': {'description': 'FN',
#       'mask': 2047,
#       'access': 'read-only'},
#      'LSOF': {'description': 'LSOF', 'mask': 6144, 'access': 'read-only'},
#      'LCK': {'description': 'LCK', 'mask': 8192, 'access': 'read-only'},
#      'RXDM': {'description': 'RXDM', 'mask': 16384, 'access': 'read-only'},
#      'RXDP': {'description': 'RXDP', 'mask': 32768, 'access': 'read-only'}}},
#    'DADDR': {'description': 'USB device address',
#     'addressOffset': 76,
#     'resetValue': 0,
#     'fields': {'ADD': {'description': 'ADD',
#       'mask': 127,
#       'access': 'read-write'},
#      'EF': {'description': 'EF', 'mask': 128, 'access': 'read-write'}}},
#    'BTABLE': {'description': 'Buffer table address',
#     'addressOffset': 80,
#     'resetValue': 0,
#     'fields': {'BTABLE': {'description': 'BTABLE',
#       'mask': 65528,
#       'access': 'read-write'}}}}},
#  'CRS': {'address': 1073750016,
#   'description': 'CRS',
#   'registers': {'CR': {'description': 'CRS control register',
#     'addressOffset': 0,
#     'resetValue': 16384,
#     'fields': {'SYNCOKIE': {'description': 'SYNC event OK interrupt enable',
#       'mask': 1,
#       'access': 'read-write'},
#      'SYNCWARNIE': {'description': 'SYNC warning interrupt enable',
#       'mask': 2,
#       'access': 'read-write'},
#      'ERRIE': {'description': 'Synchronization or trimming error interrupt enable',
#       'mask': 4,
#       'access': 'read-write'},
#      'ESYNCIE': {'description': 'Expected SYNC interrupt enable',
#       'mask': 8,
#       'access': 'read-write'},
#      'CEN': {'description': 'Frequency error counter enable This bit enables the oscillator clock for the frequency error counter. When this bit is set, the CRS_CFGR register is write-protected and cannot be modified.',
#       'mask': 32,
#       'access': 'read-write'},
#      'AUTOTRIMEN': {'description': 'Automatic trimming enable This bit enables the automatic hardware adjustment of TRIM bits according to the measured frequency error between two SYNC events. If this bit is set, the TRIM bits are read-only. The TRIM value can be adjusted by hardware by one or two steps at a time, depending on the measured frequency error value. Refer to Section7.3.4: Frequency error evaluation and automatic trimming for more details.',
#       'mask': 64,
#       'access': 'read-write'},
#      'SWSYNC': {'description': 'Generate software SYNC event This bit is set by software in order to generate a software SYNC event. It is automatically cleared by hardware.',
#       'mask': 128,
#       'access': 'read-write'},
#      'TRIM': {'description': 'HSI48 oscillator smooth trimming These bits provide a user-programmable trimming value to the HSI48 oscillator. They can be programmed to adjust to variations in voltage and temperature that influence the frequency of the HSI48. The default value is 32, which corresponds to the middle of the trimming interval. The trimming step is around 67 kHz between two consecutive TRIM steps. A higher TRIM value corresponds to a higher output frequency. When the AUTOTRIMEN bit is set, this field is controlled by hardware and is read-only.',
#       'mask': 32512,
#       'access': 'read-write'}}},
#    'CFGR': {'description': 'This register can be written only when the frequency error counter is disabled (CEN bit is cleared in CRS_CR). When the counter is enabled, this register is write-protected.',
#     'addressOffset': 4,
#     'resetValue': 539147135,
#     'fields': {'RELOAD': {'description': 'Counter reload value RELOAD is the value to be loaded in the frequency error counter with each SYNC event. Refer to Section7.3.3: Frequency error measurement for more details about counter behavior.',
#       'mask': 65535,
#       'access': 'read-write'},
#      'FELIM': {'description': 'Frequency error limit FELIM contains the value to be used to evaluate the captured frequency error value latched in the FECAP[15:0] bits of the CRS_ISR register. Refer to Section7.3.4: Frequency error evaluation and automatic trimming for more details about FECAP evaluation.',
#       'mask': 16711680,
#       'access': 'read-write'},
#      'SYNCDIV': {'description': 'SYNC divider These bits are set and cleared by software to control the division factor of the SYNC signal.',
#       'mask': 117440512,
#       'access': 'read-write'},
#      'SYNCSRC': {'description': 'SYNC signal source selection These bits are set and cleared by software to select the SYNC signal source. Note: When using USB LPM (Link Power Management) and the device is in Sleep mode, the periodic USB SOF will not be generated by the host. No SYNC signal will therefore be provided to the CRS to calibrate the HSI48 on the run. To guarantee the required clock precision after waking up from Sleep mode, the LSE or reference clock on the GPIOs should be used as SYNC signal.',
#       'mask': 805306368,
#       'access': 'read-write'},
#      'SYNCPOL': {'description': 'SYNC polarity selection This bit is set and cleared by software to select the input polarity for the SYNC signal source.',
#       'mask': 2147483648,
#       'access': 'read-write'}}},
#    'ISR': {'description': 'CRS interrupt and status register',
#     'addressOffset': 8,
#     'resetValue': 0,
#     'fields': {'SYNCOKF': {'description': 'SYNC event OK flag This flag is set by hardware when the measured frequency error is smaller than FELIM * 3. This means that either no adjustment of the TRIM value is needed or that an adjustment by one trimming step is enough to compensate the frequency error. An interrupt is generated if the SYNCOKIE bit is set in the CRS_CR register. It is cleared by software by setting the SYNCOKC bit in the CRS_ICR register.',
#       'mask': 1,
#       'access': 'read-only'},
#      'SYNCWARNF': {'description': 'SYNC warning flag This flag is set by hardware when the measured frequency error is greater than or equal to FELIM * 3, but smaller than FELIM * 128. This means that to compensate the frequency error, the TRIM value must be adjusted by two steps or more. An interrupt is generated if the SYNCWARNIE bit is set in the CRS_CR register. It is cleared by software by setting the SYNCWARNC bit in the CRS_ICR register.',
#       'mask': 2,
#       'access': 'read-only'},
#      'ERRF': {'description': 'Error flag This flag is set by hardware in case of any synchronization or trimming error. It is the logical OR of the TRIMOVF, SYNCMISS and SYNCERR bits. An interrupt is generated if the ERRIE bit is set in the CRS_CR register. It is cleared by software in reaction to setting the ERRC bit in the CRS_ICR register, which clears the TRIMOVF, SYNCMISS and SYNCERR bits.',
#       'mask': 4,
#       'access': 'read-only'},
#      'ESYNCF': {'description': 'Expected SYNC flag This flag is set by hardware when the frequency error counter reached a zero value. An interrupt is generated if the ESYNCIE bit is set in the CRS_CR register. It is cleared by software by setting the ESYNCC bit in the CRS_ICR register.',
#       'mask': 8,
#       'access': 'read-only'},
#      'SYNCERR': {'description': 'SYNC error This flag is set by hardware when the SYNC pulse arrives before the ESYNC event and the measured frequency error is greater than or equal to FELIM * 128. This means that the frequency error is too big (internal frequency too low) to be compensated by adjusting the TRIM value, and that some other action should be taken. An interrupt is generated if the ERRIE bit is set in the CRS_CR register. It is cleared by software by setting the ERRC bit in the CRS_ICR register.',
#       'mask': 256,
#       'access': 'read-only'},
#      'SYNCMISS': {'description': 'SYNC missed This flag is set by hardware when the frequency error counter reached value FELIM * 128 and no SYNC was detected, meaning either that a SYNC pulse was missed or that the frequency error is too big (internal frequency too high) to be compensated by adjusting the TRIM value, and that some other action should be taken. At this point, the frequency error counter is stopped (waiting for a next SYNC) and an interrupt is generated if the ERRIE bit is set in the CRS_CR register. It is cleared by software by setting the ERRC bit in the CRS_ICR register.',
#       'mask': 512,
#       'access': 'read-only'},
#      'TRIMOVF': {'description': 'Trimming overflow or underflow This flag is set by hardware when the automatic trimming tries to over- or under-flow the TRIM value. An interrupt is generated if the ERRIE bit is set in the CRS_CR register. It is cleared by software by setting the ERRC bit in the CRS_ICR register.',
#       'mask': 1024,
#       'access': 'read-only'},
#      'FEDIR': {'description': 'Frequency error direction FEDIR is the counting direction of the frequency error counter latched in the time of the last SYNC event. It shows whether the actual frequency is below or above the target.',
#       'mask': 32768,
#       'access': 'read-only'},
#      'FECAP': {'description': 'Frequency error capture FECAP is the frequency error counter value latched in the time ofthe last SYNC event. Refer to Section7.3.4: Frequency error evaluation and automatic trimming for more details about FECAP usage.',
#       'mask': 4294901760,
#       'access': 'read-only'}}},
#    'ICR': {'description': 'CRS interrupt flag clear register',
#     'addressOffset': 12,
#     'resetValue': 0,
#     'fields': {'SYNCOKC': {'description': 'SYNC event OK clear flag Writing 1 to this bit clears the SYNCOKF flag in the CRS_ISR register.',
#       'mask': 1,
#       'access': 'read-write'},
#      'SYNCWARNC': {'description': 'SYNC warning clear flag Writing 1 to this bit clears the SYNCWARNF flag in the CRS_ISR register.',
#       'mask': 2,
#       'access': 'read-write'},
#      'ERRC': {'description': 'Error clear flag Writing 1 to this bit clears TRIMOVF, SYNCMISS and SYNCERR bits and consequently also the ERRF flag in the CRS_ISR register.',
#       'mask': 4,
#       'access': 'read-write'},
#      'ESYNCC': {'description': 'Expected SYNC clear flag Writing 1 to this bit clears the ESYNCF flag in the CRS_ISR register.',
#       'mask': 8,
#       'access': 'read-write'}}}}}}

# %%
def find_arrays(ls):
    results = set()
    re_last_digits = r"(\d+)(?!.*\d)"

    for s in ls:
        if re.findall(re_last_digits, s):
            n = int(re.findall(re_last_digits, s)[0])
            fmt = re.sub(re_last_digits, "{}", s)
            if fmt not in results and \
                fmt.format("") not in ls and \
                fmt.format(n+1) in ls and\
                fmt != "CR{}":
                results.add(fmt)
    
    return results

# %%
f = open(f"./{model}.py", "w")
f.write("from seracc import BitField, RegisterBase, PeripheralBase, Subscriptor\n")
f.write("from seracc import logging, wait_until_equal\n")
# Out:
# 45

# %%
for periname, periinfo in info.items():
    if "base" in periinfo:
        f.write(f"""\
{periname} = SA_{periinfo["base"]}(0x{periinfo["address"]:08X}, \"{periname}\")
""")
        continue

    peri_class = f"""
class SA_{periname}(PeripheralBase):

    def __init__(self, base, name):
        super().__init__(base, name, \"{periinfo["description"]}\")
"""
    
    for regname, reginfo in periinfo["registers"].items():
        classname = f"{periname}_{regname}"
        offset = reginfo["addressOffset"]
        peri_class += f"""\
        self.{regname} = SA_{classname}(self, 0x{offset:X})
"""
        
        reg_class = f"""
class SA_{classname}(RegisterBase):
    
    def __init__(self, peripheral, offset):
        super().__init__(peripheral, offset, 0x{reginfo["resetValue"]:X}, \"{regname}\", \"{reginfo["description"]}\")
"""
        for fieldname, fieldinfo in reginfo["fields"].items():
            reg_class += f"""\
        self.{fieldname} = BitField(self, 0x{fieldinfo["mask"]:08X}, \"{fieldname}\", \"{fieldinfo["description"]}\")
"""
        
        for format in find_arrays(reginfo["fields"].keys()):
            reg_class += f"""\
        self.{format.format("")} = Subscriptor(self, \"{format}\")
"""
        
        f.write(reg_class)

    for format in find_arrays(periinfo["registers"].keys()):
        peri_class += f"""\
        self.{format.format("")} = Subscriptor(self, \"{format}\")
"""
    
    peri_class += f"""
{periname} = SA_{periname}(0x{periinfo["address"]:08X}, \"{periname}\")
"""
    f.write(peri_class)

# %%
f.close()
